# %%
#Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('customer_retention_dataset.xlsx')
df.head(5)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
#Fragmenting the original dataset into separate dataframes for easy processing
df1=df.iloc[:, 0:17]
df1
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df1.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df1.rename(
    columns={'1Gender of respondent': "Gender",
            '2 How old are you? ': "Age",
            '3 Which city do you shop online from?': "City",
            '4 What is the Pin Code of where you shop online from?': "Pincode",
            '5 Since How Long You are Shopping Online ?': "YearsofOnlineshopping",
            '6 How many times you have made an online purchase in the past 1 year?': "FreqOnlinePurchaseslastyear",
            '7 How do you access the internet while shopping on-line?': "InternetSource",
            '8 Which device do you use to access the online shopping?': "DeviceUsed",
            '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ': "ScreenSizeMobile",
            '10 What is the operating system (OS) of your device?\t\t\t\t                                          ': "OSofdevice",         
            '11 What browser do you run on your device to access the website?\t\t\t                                                          ': "BrowserUsed",
            '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ': "Channelusedfirsttime",
            '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ': "Onlinestoresecondreach",
            '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ': "Timespentbeforepurchase", 
            '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ': "PreferredpaymentOption", 
            '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ': "FreqAbandoningshoppingcart", 
            '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ': "Reasonsforabandoning"})
# Out:
#      Gender                 Age           City  Pincode YearsofOnlineshopping  \
# 0      Male         31-40 years          Delhi   110009         Above 4 years
# 1    Female         21-30 years          Delhi   110030         Above 4 years
# 2    Female         21-30 years  Greater Noida   201308             3-4 years
# 3      Male         21-30 years        Karnal    132001             3-4 years
# 4    Female         21-30 years     Bangalore    530068             2-3 years
# ..      ...                 ...            ...      ...                   ...
# 264  Female         21-30 years          Solan   173212             1-2 years
# 265  Female         31-40 years      Ghaziabad   201008             1-2 years
# 266  Female         41-50 yaers     Bangalore    560010             2-3 years
# 267  Female  Less than 20 years          Solan   173229             2-3 years
# 268  Female         41-50 yaers      Ghaziabad   201009             2-3 years
#
# ...

# %%
df2=df.iloc[:, 17:47]
df2
# Out:
#     18 The content on the website must be easy to read and understand  \
# 0                                            Agree (4)
# 1                                   Strongly agree (5)
# 2                                   Strongly agree (5)
# 3                                            Agree (4)
# 4                                   Strongly agree (5)
# ..                                                 ...
# 264                                          Agree (4)
# 265                                 Strongly agree (5)
# 266                                 Strongly agree (5)
# 267                                 Strongly agree (5)
# 268                                 Strongly agree (5)
#
#     19 Information on similar product to the one highlighted  is important for product comparison  \
# 0                                      Indifferent (3)
# 1                                   Strongly agree (5)
# 2                                            Agree (4)
# ...

# %%
df2.columns
# Out:
# Index(['18 The content on the website must be easy to read and understand',
#        '19 Information on similar product to the one highlighted  is important for product comparison',
#        '20 Complete information on listed seller and product being offered is important for purchase decision.',
#        '21 All relevant information on listed products must be stated clearly',
#        '22 Ease of navigation in website', '23 Loading and processing speed',
#        '24 User friendly Interface of the website',
#        '25 Convenient Payment methods',
#        '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
#        '27 Empathy (readiness to assist with queries) towards the customers',
#        '28 Being able to guarantee the privacy of the customer',
#        '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
# ...

# %%
df2_sh=pd.melt(df2, var_name='Statements', value_name='Responses')
df2_sh.tail(20)
# Out:
#                             Statements           Responses
# 8050  47 Getting value for money spent  Strongly agree (5)
# 8051  47 Getting value for money spent  Strongly agree (5)
# 8052  47 Getting value for money spent     indifferent (3)
# 8053  47 Getting value for money spent           Agree (4)
# 8054  47 Getting value for money spent           Agree (4)
# 8055  47 Getting value for money spent           Agree (4)
# 8056  47 Getting value for money spent     indifferent (3)
# 8057  47 Getting value for money spent           Agree (4)
# 8058  47 Getting value for money spent           Agree (4)
# 8059  47 Getting value for money spent  Strongly agree (5)
# 8060  47 Getting value for money spent  Strongly agree (5)
# 8061  47 Getting value for money spent  Strongly agree (5)
# 8062  47 Getting value for money spent           Agree (4)
# 8063  47 Getting value for money spent  Strongly agree (5)
# 8064  47 Getting value for money spent           Agree (4)
# ...

# %%
df3=df.iloc[:, 47:71]
df3
# Out:
#     From the following, tick any (or all) of the online retailers you have shopped from;                                                                             \
# 0                                 Amazon.in, Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                     Amazon.in, Paytm.com, Myntra.com
# 3    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# ..                                                 ...
# 264                                          Amazon.in
# 265                            Amazon.in, Flipkart.com
# 266              Amazon.in, Flipkart.com, Snapdeal.com
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                     Easy to use website or application  \
# 0                                            Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# ...

# %%
df3.columns
# Out:
# Index(['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
#        'Easy to use website or application',
#        'Visual appealing web-page layout', 'Wild variety of product on offer',
#        'Complete, relevant description information of products',
#        'Fast loading website speed of website and application',
#        'Reliability of the website or application',
#        'Quickness to complete purchase',
#        'Availability of several payment options', 'Speedy order delivery ',
#        'Privacy of customers’ information',
#        'Security of customer financial information',
#        'Perceived Trustworthiness',
#        'Presence of online assistance through multi-channel',
#        'Longer time to get logged in (promotion, sales period)',
#        'Longer time in displaying graphics and photos (promotion, sales period)',
# ...

# %%
df3_sh=pd.melt(df3, var_name='Tech_Features', value_name='Ecomm_Websites')
df3_sh.head(20)
# Out:
#                                         Tech_Features  \
# 0   From the following, tick any (or all) of the o...
# 1   From the following, tick any (or all) of the o...
# 2   From the following, tick any (or all) of the o...
# 3   From the following, tick any (or all) of the o...
# 4   From the following, tick any (or all) of the o...
# 5   From the following, tick any (or all) of the o...
# 6   From the following, tick any (or all) of the o...
# 7   From the following, tick any (or all) of the o...
# 8   From the following, tick any (or all) of the o...
# 9   From the following, tick any (or all) of the o...
# 10  From the following, tick any (or all) of the o...
# 11  From the following, tick any (or all) of the o...
# 12  From the following, tick any (or all) of the o...
# 13  From the following, tick any (or all) of the o...
# 14  From the following, tick any (or all) of the o...
# 15  From the following, tick any (or all) of the o...
# ...

# %%
var_split=df3_sh["Ecomm_Websites"].str.split(',')

# %%
var_split
# Out:
# 0                                 [Amazon.in,  Paytm.com]
# 1       [Amazon.in,  Flipkart.com,  Myntra.com,  Snapd...
# 2                    [Amazon.in,  Paytm.com,  Myntra.com]
# 3       [Amazon.in,  Flipkart.com,  Paytm.com,  Myntra...
# 4       [Amazon.in,  Flipkart.com,  Paytm.com,  Myntra...
#                               ...
# 6451                                          [Amazon.in]
# 6452                                       [Flipkart.com]
# 6453                                          [Amazon.in]
# 6454                                          [Amazon.in]
# 6455                                          [Amazon.in]
# Name: Ecomm_Websites, Length: 6456, dtype: object

# %%
var_split.str.get(0)
# Out:
# 0          Amazon.in
# 1          Amazon.in
# 2          Amazon.in
# 3          Amazon.in
# 4          Amazon.in
#             ...
# 6451       Amazon.in
# 6452    Flipkart.com
# 6453       Amazon.in
# 6454       Amazon.in
# 6455       Amazon.in
# Name: Ecomm_Websites, Length: 6456, dtype: object

# %%
var_split.str.get(3)
# Out:
# 0                 NaN
# 1        Snapdeal.com
# 2                 NaN
# 3          Myntra.com
# 4          Myntra.com
#             ...
# 6451              NaN
# 6452              NaN
# 6453              NaN
# 6454              NaN
# 6455              NaN
# Name: Ecomm_Websites, Length: 6456, dtype: object

# %%
df3_sh["Website1"]=var_split.str.get(0)
df3_sh["Website2"]=var_split.str.get(1)
df3_sh["Website3"]=var_split.str.get(2)
df3_sh["Website4"]=var_split.str.get(3)
df3_sh["Website5"]=var_split.str.get(4)

# %%
df3_sh.tail(20)
# Out:
#                                           Tech_Features  \
# 6436  Which of the Indian online retailer would you ...
# 6437  Which of the Indian online retailer would you ...
# 6438  Which of the Indian online retailer would you ...
# 6439  Which of the Indian online retailer would you ...
# 6440  Which of the Indian online retailer would you ...
# 6441  Which of the Indian online retailer would you ...
# 6442  Which of the Indian online retailer would you ...
# 6443  Which of the Indian online retailer would you ...
# 6444  Which of the Indian online retailer would you ...
# 6445  Which of the Indian online retailer would you ...
# 6446  Which of the Indian online retailer would you ...
# 6447  Which of the Indian online retailer would you ...
# 6448  Which of the Indian online retailer would you ...
# 6449  Which of the Indian online retailer would you ...
# 6450  Which of the Indian online retailer would you ...
# 6451  Which of the Indian online retailer would you ...
# ...
